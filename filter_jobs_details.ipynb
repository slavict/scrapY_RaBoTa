# %%
import pandas as pd
df = pd.read_csv('rabota_it_jobs_details.csv')
pd.set_option('display.max_rows', None)

# %%
df.head(5)
# Out:
#                                            job_title  \
# 0   Tehnician​-​Consultant | Administrator de sistem
# 1                    Программист 1С | Programator 1C
# 2  Administrator / Administratoare funcţional(ă) ...
# 3                                 IT Project Manager
# 4                               Senior Data Engineer
#
#                        company                  location  \
# 0                   Soft Lider  În locația angajatorului
# 1                   Soft Lider  În locația angajatorului
# 2  Premier Energy Distribution  În locația angajatorului
# 3             Profmet Grup SRL  În locația angajatorului
# 4              BC Energbank SA  În locația angajatorului
#
#                                         address  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3  R. Moldova, mun. Chișinău, str. Petricani 31
# 4                                           NaN
#
# ...

# %%
df[df['company'].str.contains('stefanini', case=False) & df['job_title'].str.contains('Technical S', case=False)]
# Out:
#                       job_title    company                  location  \
# 90   Technical Support Engineer  Stefanini  În locația angajatorului
# 205  Technical Support Engineer  Stefanini  În locația angajatorului
#
#                                                address  \
# 90   Chișinău Experiența de munca: De la 1 an Progr...
# 205                               str. Sfatul Țării 29
#
#                                            description  \
# 90   We are looking for a Technical Support Enginee...
# 205  Technical Support Engineer We are looking for ...
#
#                                                    url
# 90   https://www.rabota.md/ro/joburi/technical-supp...
# 205  https://www.rabota.md/ro/locuri-de-munca/techn...

# %%
# fileter all jobs that require java, php, 1c
df[~df['job_title'].str.contains('java |php|ios|android|1c|c#|1С', regex=True, case=False)]
# Out:
#                                              job_title  \
# 0                               Middle Golang Engineer
# 1                               Senior Golang Engineer
# 4                                     Python Developer
# 5    Expert principal – Guvernanță TIC și conformit...
# 7    Преподаватель по IT ​-​ Программированию / Роб...
# 8             Specialist Administrare Website (Turism)
# 9    Specialist principal, Serviciul Gestionare Sof...
# 12   Product Owner Business, Departamentul Digital ...
# 13   Administrator, Serviciul Administrare a Rețele...
# 14       Специалист по интеграции amoCRM (Part​-​Time)
# 15                                        Data analyst
# 16         Specealist suport tehnic sisteme securitate
# 17     IT specealist suport tehnic | 15.000-18.000 lei
# 18                            Data & Impact Specialist
# 19   Fullstack Developer (Node.js / NestJS / React)...
# 20           Backend Developer (Node.js 1000-2500 USD)
# ...
