# %%
import pandas as pd
from jupyter_core.migrate import regex

df = pd.read_csv('rabota_it_jobs.csv')
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    vacancy_id                          title          company  \
# 0      137139       Консультант-внедренец 1C  Casa Del Tabaco
# 1      137131                 Программист 1С  Casa Del Tabaco
# 2      119733        Administrator de sistem  Casa Del Tabaco
# 3      102861  System Administrator Engineer   Arax Impex SRL
# 4      102794             Șef Departament IT   Arax Impex SRL
#
#        posted_time                                                url
# 0  1 minut în urmă  https://www.rabota.md/ro/locuri-de-munca/konsu...
# 1  1 minut în urmă  https://www.rabota.md/ro/locuri-de-munca/progr...
# 2  1 minut în urmă  https://www.rabota.md/ro/locuri-de-munca/admin...
# 3  1 minut în urmă  https://www.rabota.md/ro/locuri-de-munca/syste...
# 4  1 minut în urmă  https://www.rabota.md/ro/locuri-de-munca/sef-d...

# %%
df[df['title'].str.contains('[p,P]ython', regex=True)]

# %%
df[df['title'].str.contains('[r,R]eact|frontend', regex=True)]

# %%
df[df['company'].str.contains('Stefanini', regex=True)]
# Out:
#      vacancy_id                                              title    company  \
# 161      137302                   C# Application Consultant Intern  Stefanini
# 162      136919                          Mobile Engineer (Flutter)  Stefanini
# 163      135631                          C# Application Consultant  Stefanini
# 164      134299                              Senior Java Developer  Stefanini
# 165      133509  Support Engineer with Finnish (Level 1 - Entry...  Stefanini
# 166      128239                        Operational System Engineer  Stefanini
# 167      122913                         Technical Support Engineer  Stefanini
# 168      116031             Entry-Level IT Job (Training Provided)  Stefanini
# 169       36555                 Technical IT Support (Entry Level)  Stefanini
# 170      135250  Start Your IT Career – English Speakers Welcom...  Stefanini
# 286    16444639             Entry-Level IT Job (Training Provided)  Stefanini
# ...
